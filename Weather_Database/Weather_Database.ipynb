# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key
from datetime import datetime
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 788

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["main"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lockport
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | vestmannaeyjar
# Processing Record 4 of Set 1 | yar-sale
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | candido mendes
# Processing Record 8 of Set 1 | porto walter
# Processing Record 9 of Set 1 | vallenar
# Processing Record 10 of Set 1 | portland
# Processing Record 11 of Set 1 | ixtapa
# Processing Record 12 of Set 1 | richards bay
# Processing Record 13 of Set 1 | gravdal
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | luderitz
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 20 of Set 1 | los llanos de aridane
# Processing Record 21 of Set 1 | sungairaya
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | melfort
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | mazatlan
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | nome
# Processing Record 31 of Set 1 | bud
# Processing Record 32 of Set 1 | praia da vitoria
# Processing Record 33 of Set 1 | maniitsoq
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | payson
# Processing Record 36 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | atasu
# Processing Record 40 of Set 1 | ye
# City not found. Skipping...
# Processing Record 41 of Set 1 | ostrovnoy
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | uhlove
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | olean
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | haines junction
# Processing Record 49 of Set 1 | pran buri
# Processing Record 50 of Set 1 | dabakala
# Processing Record 1 of Set 2 | necochea
# Processing Record 2 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 2 | diffa
# Processing Record 4 of Set 2 | pangnirtung
# Processing Record 5 of Set 2 | itoman
# Processing Record 6 of Set 2 | ayagoz
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | sabang
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | severnyy
# Processing Record 15 of Set 2 | santa rosa
# Processing Record 16 of Set 2 | okmulgee
# Processing Record 17 of Set 2 | ingham
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | manta
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | fortuna
# Processing Record 22 of Set 2 | kupang
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | sao filipe
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | taltal
# Processing Record 27 of Set 2 | bojnurd
# Processing Record 28 of Set 2 | labuhan
# Processing Record 29 of Set 2 | eyl
# Processing Record 30 of Set 2 | chardara
# Processing Record 31 of Set 2 | fare
# Processing Record 32 of Set 2 | sao gabriel da cachoeira
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | hay river
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | syracuse
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | kyabram
# Processing Record 48 of Set 2 | kavieng
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | mao
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | kitimat
# Processing Record 3 of Set 3 | denpasar
# Processing Record 4 of Set 3 | nalut
# Processing Record 5 of Set 3 | poronaysk
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | faya
# Processing Record 8 of Set 3 | la romana
# Processing Record 9 of Set 3 | eau claire
# Processing Record 10 of Set 3 | leningradskiy
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | tigil
# Processing Record 14 of Set 3 | khash
# Processing Record 15 of Set 3 | popondetta
# Processing Record 16 of Set 3 | ferme-neuve
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | aksay
# Processing Record 19 of Set 3 | hofn
# Processing Record 20 of Set 3 | souillac
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | srednekolymsk
# Processing Record 23 of Set 3 | picota
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | codrington
# Processing Record 26 of Set 3 | hanzhong
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | vizinga
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | yatou
# Processing Record 31 of Set 3 | half moon bay
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | saint-pierre
# Processing Record 34 of Set 3 | bilibino
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | christchurch
# Processing Record 37 of Set 3 | carballo
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | kununurra
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | goundam
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | cape town
# Processing Record 45 of Set 3 | edd
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | pervomayskoye
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | saint-augustin
# Processing Record 1 of Set 4 | khomeynishahr
# City not found. Skipping...
# Processing Record 2 of Set 4 | sept-iles
# Processing Record 3 of Set 4 | jaguaquara
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 4 | canmore
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | cap malheureux
# Processing Record 9 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 4 | te anau
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 4 | chumikan
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | batagay-alyta
# Processing Record 16 of Set 4 | quatre cocos
# Processing Record 17 of Set 4 | juruti
# Processing Record 18 of Set 4 | kahului
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | bilma
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | east wenatchee bench
# Processing Record 23 of Set 4 | kapaa
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | abapo
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | manono
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | upernavik
# Processing Record 33 of Set 4 | prince rupert
# Processing Record 34 of Set 4 | noyabrsk
# Processing Record 35 of Set 4 | riyadh
# Processing Record 36 of Set 4 | paderborn
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | yellowknife
# Processing Record 42 of Set 4 | ternate
# Processing Record 43 of Set 4 | yuxia
# Processing Record 44 of Set 4 | palana
# Processing Record 45 of Set 4 | hazorasp
# Processing Record 46 of Set 4 | egvekinot
# Processing Record 47 of Set 4 | floresta
# Processing Record 48 of Set 4 | atar
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | armizonskoye
# Processing Record 1 of Set 5 | alofi
# Processing Record 2 of Set 5 | yokadouma
# Processing Record 3 of Set 5 | lata
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | mecca
# Processing Record 6 of Set 5 | jamestown
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | nuevo laredo
# Processing Record 9 of Set 5 | villa guerrero
# Processing Record 10 of Set 5 | phuthaditjhaba
# Processing Record 11 of Set 5 | idrinskoye
# Processing Record 12 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5 | melaka
# Processing Record 14 of Set 5 | fairbanks
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | coruripe
# Processing Record 17 of Set 5 | castro
# Processing Record 18 of Set 5 | foca
# Processing Record 19 of Set 5 | alice springs
# Processing Record 20 of Set 5 | maputo
# Processing Record 21 of Set 5 | bibiani
# Processing Record 22 of Set 5 | trincomalee
# Processing Record 23 of Set 5 | thunder bay
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | huarmey
# Processing Record 27 of Set 5 | baghdad
# Processing Record 28 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 5 | ulladulla
# Processing Record 30 of Set 5 | chawinda
# Processing Record 31 of Set 5 | dingle
# Processing Record 32 of Set 5 | nishihara
# Processing Record 33 of Set 5 | bustamante
# Processing Record 34 of Set 5 | druzhnaya gorka
# Processing Record 35 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 5 | arlit
# Processing Record 37 of Set 5 | ereymentau
# Processing Record 38 of Set 5 | itarema
# Processing Record 39 of Set 5 | almaznyy
# Processing Record 40 of Set 5 | astana
# Processing Record 41 of Set 5 | yangambi
# Processing Record 42 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | shitanjing
# Processing Record 45 of Set 5 | tiverton
# Processing Record 46 of Set 5 | pangoa
# Processing Record 47 of Set 5 | port blair
# Processing Record 48 of Set 5 | flinders
# Processing Record 49 of Set 5 | maceio
# Processing Record 50 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 6 | bagdarin
# Processing Record 2 of Set 6 | jaciara
# Processing Record 3 of Set 6 | ascension
# Processing Record 4 of Set 6 | san matias
# Processing Record 5 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | muros
# Processing Record 7 of Set 6 | ranong
# Processing Record 8 of Set 6 | baykit
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | oksfjord
# Processing Record 11 of Set 6 | constitucion
# Processing Record 12 of Set 6 | manuk mangkaw
# Processing Record 13 of Set 6 | erenhot
# Processing Record 14 of Set 6 | bubaque
# Processing Record 15 of Set 6 | vilyuysk
# Processing Record 16 of Set 6 | lotofaga
# Processing Record 17 of Set 6 | mananjary
# Processing Record 18 of Set 6 | codajas
# Processing Record 19 of Set 6 | shakawe
# Processing Record 20 of Set 6 | natal
# Processing Record 21 of Set 6 | makat
# Processing Record 22 of Set 6 | wolfville
# Processing Record 23 of Set 6 | kulhudhuffushi
# Processing Record 24 of Set 6 | launceston
# Processing Record 25 of Set 6 | khatanga
# Processing Record 26 of Set 6 | broome
# Processing Record 27 of Set 6 | agropoli
# Processing Record 28 of Set 6 | biggar
# Processing Record 29 of Set 6 | marsa matruh
# Processing Record 30 of Set 6 | belaya gora
# Processing Record 31 of Set 6 | minab
# Processing Record 32 of Set 6 | harindanga
# Processing Record 33 of Set 6 | ajdabiya
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | igrim
# Processing Record 36 of Set 6 | mayor pablo lagerenza
# Processing Record 37 of Set 6 | sorland
# Processing Record 38 of Set 6 | maturin
# Processing Record 39 of Set 6 | kathu
# Processing Record 40 of Set 6 | kargat
# Processing Record 41 of Set 6 | cozumel
# Processing Record 42 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 43 of Set 6 | larsnes
# Processing Record 44 of Set 6 | tual
# Processing Record 45 of Set 6 | novyy urengoy
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | villarrica
# Processing Record 48 of Set 6 | ucluelet
# Processing Record 49 of Set 6 | dedougou
# Processing Record 50 of Set 6 | katsuura
# Processing Record 1 of Set 7 | puerto penasco
# Processing Record 2 of Set 7 | deputatskiy
# Processing Record 3 of Set 7 | vardo
# Processing Record 4 of Set 7 | athabasca
# Processing Record 5 of Set 7 | tocopilla
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | la ronge
# Processing Record 8 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 7 | pedernales
# Processing Record 10 of Set 7 | bahia blanca
# Processing Record 11 of Set 7 | thompson
# Processing Record 12 of Set 7 | maues
# Processing Record 13 of Set 7 | pitimbu
# Processing Record 14 of Set 7 | axim
# Processing Record 15 of Set 7 | wellington
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | soure
# Processing Record 18 of Set 7 | kayerkan
# Processing Record 19 of Set 7 | rojhan
# Processing Record 20 of Set 7 | popovo
# Processing Record 21 of Set 7 | tungor
# Processing Record 22 of Set 7 | katobu
# Processing Record 23 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 7 | cache creek
# Processing Record 25 of Set 7 | salinas
# Processing Record 26 of Set 7 | oxford
# Processing Record 27 of Set 7 | aloleng
# Processing Record 28 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 29 of Set 7 | biltine
# Processing Record 30 of Set 7 | never
# Processing Record 31 of Set 7 | northam
# Processing Record 32 of Set 7 | pisco
# Processing Record 33 of Set 7 | susaki
# Processing Record 34 of Set 7 | maralal
# Processing Record 35 of Set 7 | tezu
# Processing Record 36 of Set 7 | porto santo
# Processing Record 37 of Set 7 | rio grande
# Processing Record 38 of Set 7 | tautira
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | bengkulu
# Processing Record 41 of Set 7 | santa cruz
# Processing Record 42 of Set 7 | samarai
# Processing Record 43 of Set 7 | burghead
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 7 | meiganga
# Processing Record 47 of Set 7 | lieksa
# Processing Record 48 of Set 7 | hohhot
# Processing Record 49 of Set 7 | ketchikan
# Processing Record 50 of Set 7 | luanda
# Processing Record 1 of Set 8 | ecully
# Processing Record 2 of Set 8 | pyaozerskiy
# Processing Record 3 of Set 8 | siyabuswa
# Processing Record 4 of Set 8 | kyren
# Processing Record 5 of Set 8 | arkhangelsk
# Processing Record 6 of Set 8 | sinnamary
# Processing Record 7 of Set 8 | strezhevoy
# Processing Record 8 of Set 8 | luangwa
# Processing Record 9 of Set 8 | lakes entrance
# Processing Record 10 of Set 8 | nampula
# Processing Record 11 of Set 8 | cayenne
# Processing Record 12 of Set 8 | skara
# Processing Record 13 of Set 8 | mbour
# Processing Record 14 of Set 8 | misratah
# Processing Record 15 of Set 8 | fort payne
# Processing Record 16 of Set 8 | aitape
# Processing Record 17 of Set 8 | beauchamps
# Processing Record 18 of Set 8 | cairns
# Processing Record 19 of Set 8 | zhezkazgan
# Processing Record 20 of Set 8 | konya
# Processing Record 21 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 8 | bartica
# Processing Record 23 of Set 8 | ust-barguzin
# Processing Record 24 of Set 8 | acarau
# Processing Record 25 of Set 8 | dawei
# Processing Record 26 of Set 8 | norman wells
# Processing Record 27 of Set 8 | kiboga
# Processing Record 28 of Set 8 | wakkanai
# Processing Record 29 of Set 8 | uyar
# Processing Record 30 of Set 8 | puerto escondido
# Processing Record 31 of Set 8 | burica
# City not found. Skipping...
# Processing Record 32 of Set 8 | kysyl-syr
# Processing Record 33 of Set 8 | krasnyy yar
# Processing Record 34 of Set 8 | yayva
# Processing Record 35 of Set 8 | katherine
# Processing Record 36 of Set 8 | port macquarie
# Processing Record 37 of Set 8 | salto
# Processing Record 38 of Set 8 | salym
# Processing Record 39 of Set 8 | taonan
# Processing Record 40 of Set 8 | paamiut
# Processing Record 41 of Set 8 | agstafa
# City not found. Skipping...
# Processing Record 42 of Set 8 | mobaye
# Processing Record 43 of Set 8 | saint george
# Processing Record 44 of Set 8 | wiang sa
# Processing Record 45 of Set 8 | corocito
# Processing Record 46 of Set 8 | bandarbeyla
# Processing Record 47 of Set 8 | udachnyy
# Processing Record 48 of Set 8 | carikar
# City not found. Skipping...
# Processing Record 49 of Set 8 | alcaniz
# Processing Record 50 of Set 8 | lokosovo
# Processing Record 1 of Set 9 | port hardy
# Processing Record 2 of Set 9 | ciudad guayana
# Processing Record 3 of Set 9 | high level
# Processing Record 4 of Set 9 | kieta
# Processing Record 5 of Set 9 | mercedes
# Processing Record 6 of Set 9 | la asuncion
# Processing Record 7 of Set 9 | khonsar
# City not found. Skipping...
# Processing Record 8 of Set 9 | kutum
# Processing Record 9 of Set 9 | nakatsu
# Processing Record 10 of Set 9 | ormara
# Processing Record 11 of Set 9 | iqaluit
# Processing Record 12 of Set 9 | nisia floresta
# Processing Record 13 of Set 9 | ulaanbaatar
# Processing Record 14 of Set 9 | sterling
# Processing Record 15 of Set 9 | xichang
# Processing Record 16 of Set 9 | springdale
# Processing Record 17 of Set 9 | sembe
# Processing Record 18 of Set 9 | shiraoi
# Processing Record 19 of Set 9 | marystown
# Processing Record 20 of Set 9 | humaita
# Processing Record 21 of Set 9 | guarapari
# Processing Record 22 of Set 9 | dakar
# Processing Record 23 of Set 9 | aleksandrov gay
# Processing Record 24 of Set 9 | blagoyevo
# Processing Record 25 of Set 9 | bermejo
# Processing Record 26 of Set 9 | zverinogolovskoye
# Processing Record 27 of Set 9 | port augusta
# Processing Record 28 of Set 9 | ankpa
# Processing Record 29 of Set 9 | kabo
# Processing Record 30 of Set 9 | mizan teferi
# Processing Record 31 of Set 9 | olafsvik
# Processing Record 32 of Set 9 | ponta do sol
# Processing Record 33 of Set 9 | shanhetun
# Processing Record 34 of Set 9 | sheltozero
# Processing Record 35 of Set 9 | the valley
# Processing Record 36 of Set 9 | oktyabrskiy
# Processing Record 37 of Set 9 | obihiro
# Processing Record 38 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 9 | soroca
# Processing Record 40 of Set 9 | bowen
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | dudinka
# Processing Record 43 of Set 9 | berdigestyakh
# Processing Record 44 of Set 9 | peniche
# Processing Record 45 of Set 9 | sisimiut
# Processing Record 46 of Set 9 | along
# Processing Record 47 of Set 9 | mataram
# Processing Record 48 of Set 9 | hobbs
# Processing Record 49 of Set 9 | saint-georges
# Processing Record 50 of Set 9 | nacala
# Processing Record 1 of Set 10 | aksarka
# Processing Record 2 of Set 10 | marabba
# Processing Record 3 of Set 10 | marihatag
# Processing Record 4 of Set 10 | mackay
# Processing Record 5 of Set 10 | nchelenge
# Processing Record 6 of Set 10 | bulgan
# Processing Record 7 of Set 10 | broken hill
# Processing Record 8 of Set 10 | nuuk
# Processing Record 9 of Set 10 | baiyin
# Processing Record 10 of Set 10 | vuktyl
# Processing Record 11 of Set 10 | alekseyevsk
# Processing Record 12 of Set 10 | palmer
# Processing Record 13 of Set 10 | asau
# Processing Record 14 of Set 10 | solnechnyy
# Processing Record 15 of Set 10 | waipawa
# Processing Record 16 of Set 10 | guangshui
# Processing Record 17 of Set 10 | novoagansk
# Processing Record 18 of Set 10 | sukagawa
# Processing Record 19 of Set 10 | zhanakorgan
# Processing Record 20 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 10 | ambanja
# Processing Record 22 of Set 10 | shiyan
# Processing Record 23 of Set 10 | chemax
# Processing Record 24 of Set 10 | pochutla
# Processing Record 25 of Set 10 | meadow lake
# Processing Record 26 of Set 10 | qaqortoq
# Processing Record 27 of Set 10 | taiyuan
# Processing Record 28 of Set 10 | alibag
# Processing Record 29 of Set 10 | springbok
# Processing Record 30 of Set 10 | vanimo
# Processing Record 31 of Set 10 | nemuro
# Processing Record 32 of Set 10 | shingu
# Processing Record 33 of Set 10 | leh
# Processing Record 34 of Set 10 | port arthur
# Processing Record 35 of Set 10 | berlevag
# Processing Record 36 of Set 10 | gayeri
# Processing Record 37 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 10 | kamenka
# Processing Record 39 of Set 10 | panaba
# Processing Record 40 of Set 10 | ust-tsilma
# Processing Record 41 of Set 10 | san quintin
# Processing Record 42 of Set 10 | ouidah
# Processing Record 43 of Set 10 | romny
# Processing Record 44 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 10 | bichena
# Processing Record 46 of Set 10 | sola
# Processing Record 47 of Set 10 | badvel
# Processing Record 48 of Set 10 | yulara
# Processing Record 49 of Set 10 | balabac
# Processing Record 50 of Set 10 | zhangye
# Processing Record 1 of Set 11 | ilulissat
# Processing Record 2 of Set 11 | jinka
# Processing Record 3 of Set 11 | flin flon
# Processing Record 4 of Set 11 | dharchula
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | sampit
# Processing Record 7 of Set 11 | kushmurun
# Processing Record 8 of Set 11 | shumyachi
# Processing Record 9 of Set 11 | sidi ali
# Processing Record 10 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 11 of Set 11 | pacasmayo
# Processing Record 12 of Set 11 | nouadhibou
# Processing Record 13 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 11 | chicama
# Processing Record 15 of Set 11 | campbell river
# Processing Record 16 of Set 11 | manokwari
# Processing Record 17 of Set 11 | isla vista
# Processing Record 18 of Set 11 | ndele
# Processing Record 19 of Set 11 | nizwa
# Processing Record 20 of Set 11 | shenjiamen
# Processing Record 21 of Set 11 | businga
# Processing Record 22 of Set 11 | soto la marina
# Processing Record 23 of Set 11 | mezen
# Processing Record 24 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 11 | alyangula
# Processing Record 26 of Set 11 | paciran
# Processing Record 27 of Set 11 | lagoa
# Processing Record 28 of Set 11 | rovaniemi
# Processing Record 29 of Set 11 | charlestown
# Processing Record 30 of Set 11 | dubai
# Processing Record 31 of Set 11 | mount vernon
# Processing Record 32 of Set 11 | chapais
# Processing Record 33 of Set 11 | marsaxlokk
# Processing Record 34 of Set 11 | nurota
# Processing Record 35 of Set 11 | taos
# Processing Record 36 of Set 11 | tuatapere
# Processing Record 37 of Set 11 | tralee
# Processing Record 38 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 11 | hopkinsville
# Processing Record 40 of Set 11 | abbeville
# Processing Record 41 of Set 11 | wasilla
# Processing Record 42 of Set 11 | ballina
# Processing Record 43 of Set 11 | tanjong sepat
# City not found. Skipping...
# Processing Record 44 of Set 11 | great yarmouth
# Processing Record 45 of Set 11 | vila
# Processing Record 46 of Set 11 | sur
# Processing Record 47 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 48 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 11 | pietersburg
# Processing Record 50 of Set 11 | brae
# Processing Record 1 of Set 12 | palauig
# Processing Record 2 of Set 12 | pangody
# Processing Record 3 of Set 12 | jinxiang
# Processing Record 4 of Set 12 | grand gaube
# Processing Record 5 of Set 12 | shelburne
# Processing Record 6 of Set 12 | ahipara
# Processing Record 7 of Set 12 | luwuk
# Processing Record 8 of Set 12 | maldonado
# Processing Record 9 of Set 12 | sao joao da barra
# Processing Record 10 of Set 12 | beira
# Processing Record 11 of Set 12 | jaumave
# Processing Record 12 of Set 12 | alta floresta
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | liverpool
# Processing Record 15 of Set 12 | atka
# City not found. Skipping...
# Processing Record 16 of Set 12 | traverse city
# Processing Record 17 of Set 12 | nioro
# Processing Record 18 of Set 12 | bandar-e lengeh
# Processing Record 19 of Set 12 | fonte boa
# Processing Record 20 of Set 12 | hare bay
# Processing Record 21 of Set 12 | coquimbo
# Processing Record 22 of Set 12 | rocha
# Processing Record 23 of Set 12 | loiza
# Processing Record 24 of Set 12 | vanavara
# Processing Record 25 of Set 12 | grand baie
# Processing Record 26 of Set 12 | najran
# Processing Record 27 of Set 12 | camacha
# Processing Record 28 of Set 12 | rundu
# Processing Record 29 of Set 12 | jutai
# Processing Record 30 of Set 12 | casablanca
# Processing Record 31 of Set 12 | severnoye
# Processing Record 32 of Set 12 | rawson
# Processing Record 33 of Set 12 | puerto narino
# Processing Record 34 of Set 12 | puerto plata
# Processing Record 35 of Set 12 | dehu
# Processing Record 36 of Set 12 | gusau
# Processing Record 37 of Set 12 | poya
# Processing Record 38 of Set 12 | dunedin
# Processing Record 39 of Set 12 | carman
# Processing Record 40 of Set 12 | ambulu
# Processing Record 41 of Set 12 | cefalu
# Processing Record 42 of Set 12 | pizarro
# Processing Record 43 of Set 12 | nelson
# Processing Record 44 of Set 12 | lavrentiya
# Processing Record 45 of Set 12 | araouane
# Processing Record 46 of Set 12 | guerrero negro
# Processing Record 47 of Set 12 | langxiang
# Processing Record 48 of Set 12 | shimoda
# Processing Record 49 of Set 12 | bentiu
# Processing Record 50 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 13 | burnie
# Processing Record 2 of Set 13 | castelo do piaui
# Processing Record 3 of Set 13 | badnawar
# Processing Record 4 of Set 13 | erdaojiang
# Processing Record 5 of Set 13 | bridlington
# Processing Record 6 of Set 13 | manzhouli
# Processing Record 7 of Set 13 | butiama
# Processing Record 8 of Set 13 | valkeala
# Processing Record 9 of Set 13 | sanbu
# Processing Record 10 of Set 13 | alvaraes
# Processing Record 11 of Set 13 | olinda
# Processing Record 12 of Set 13 | kashi
# Processing Record 13 of Set 13 | katima mulilo
# Processing Record 14 of Set 13 | de-kastri
# Processing Record 15 of Set 13 | milkovo
# Processing Record 16 of Set 13 | song phi nong
# Processing Record 17 of Set 13 | madang
# Processing Record 18 of Set 13 | nakusp
# Processing Record 19 of Set 13 | moose factory
# Processing Record 20 of Set 13 | tarakan
# Processing Record 21 of Set 13 | skibbereen
# Processing Record 22 of Set 13 | rio gallegos
# Processing Record 23 of Set 13 | vila velha
# Processing Record 24 of Set 13 | taki
# Processing Record 25 of Set 13 | mayumba
# Processing Record 26 of Set 13 | sakaiminato
# Processing Record 27 of Set 13 | lerwick
# Processing Record 28 of Set 13 | jardim
# Processing Record 29 of Set 13 | puqi
# Processing Record 30 of Set 13 | pitkyaranta
# Processing Record 31 of Set 13 | san jose de guanipa
# Processing Record 32 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 13 | terney
# Processing Record 34 of Set 13 | pahalgam
# Processing Record 35 of Set 13 | ankazoabo
# Processing Record 36 of Set 13 | tadine
# Processing Record 37 of Set 13 | cruz
# Processing Record 38 of Set 13 | stillwater
# Processing Record 39 of Set 13 | szczecin
# Processing Record 40 of Set 13 | sandane
# Processing Record 41 of Set 13 | greensburg
# Processing Record 42 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 13 | san juan
# Processing Record 44 of Set 13 | mirabad
# Processing Record 45 of Set 13 | gualaquiza
# Processing Record 46 of Set 13 | trairi
# Processing Record 47 of Set 13 | camacupa
# Processing Record 48 of Set 13 | namatanai
# Processing Record 49 of Set 13 | klaksvik
# Processing Record 50 of Set 13 | yenagoa
# Processing Record 1 of Set 14 | sambava
# Processing Record 2 of Set 14 | atikokan
# Processing Record 3 of Set 14 | atherton
# Processing Record 4 of Set 14 | port lincoln
# Processing Record 5 of Set 14 | bintulu
# Processing Record 6 of Set 14 | walvis bay
# Processing Record 7 of Set 14 | tongchuan
# Processing Record 8 of Set 14 | esperance
# Processing Record 9 of Set 14 | maungatapere
# Processing Record 10 of Set 14 | timmins
# Processing Record 11 of Set 14 | bontang
# Processing Record 12 of Set 14 | ambon
# Processing Record 13 of Set 14 | harwich
# Processing Record 14 of Set 14 | windhoek
# Processing Record 15 of Set 14 | koumac
# Processing Record 16 of Set 14 | seminole
# Processing Record 17 of Set 14 | salamina
# Processing Record 18 of Set 14 | hovd
# Processing Record 19 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 20 of Set 14 | sobolevo
# Processing Record 21 of Set 14 | bacungan
# Processing Record 22 of Set 14 | guanica
# Processing Record 23 of Set 14 | port-cartier
# Processing Record 24 of Set 14 | chitrakonda
# Processing Record 25 of Set 14 | laguna
# Processing Record 26 of Set 14 | semnan
# Processing Record 27 of Set 14 | antalaha
# Processing Record 28 of Set 14 | padang
# Processing Record 29 of Set 14 | lethem
# Processing Record 30 of Set 14 | cartagena
# Processing Record 31 of Set 14 | plettenberg bay
# Processing Record 32 of Set 14 | clyde river
# Processing Record 33 of Set 14 | le vauclin
# Processing Record 34 of Set 14 | mkushi
# Processing Record 35 of Set 14 | shangrao
# Processing Record 36 of Set 14 | agirish
# Processing Record 37 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 14 | nago
# Processing Record 39 of Set 14 | kompaniyivka
# Processing Record 40 of Set 14 | jawhar
# Processing Record 41 of Set 14 | banamba
# Processing Record 42 of Set 14 | neryungri
# Processing Record 43 of Set 14 | bereznik
# Processing Record 44 of Set 14 | andenes
# Processing Record 45 of Set 14 | bekhtery
# Processing Record 46 of Set 14 | taclobo
# Processing Record 47 of Set 14 | swan river
# Processing Record 48 of Set 14 | marawi
# Processing Record 49 of Set 14 | bonga
# Processing Record 50 of Set 14 | oktyabrskoye
# Processing Record 1 of Set 15 | kalemie
# Processing Record 2 of Set 15 | camapua
# Processing Record 3 of Set 15 | praya
# Processing Record 4 of Set 15 | iranshahr
# Processing Record 5 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 15 | chokwe
# Processing Record 7 of Set 15 | baruun-urt
# Processing Record 8 of Set 15 | dourbali
# Processing Record 9 of Set 15 | lynden
# Processing Record 10 of Set 15 | kushima
# Processing Record 11 of Set 15 | adrar
# Processing Record 12 of Set 15 | viedma
# Processing Record 13 of Set 15 | batemans bay
# Processing Record 14 of Set 15 | burgeo
# Processing Record 15 of Set 15 | capitao poco
# Processing Record 16 of Set 15 | den helder
# Processing Record 17 of Set 15 | touros
# Processing Record 18 of Set 15 | barcelos
# Processing Record 19 of Set 15 | gangoh
# Processing Record 20 of Set 15 | tshikapa
# Processing Record 21 of Set 15 | ugoofaaru
# Processing Record 22 of Set 15 | jalu
# Processing Record 23 of Set 15 | kropotkin
# Processing Record 24 of Set 15 | niigata
# Processing Record 25 of Set 15 | newport
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | roma
# Processing Record 28 of Set 15 | lahat
# Processing Record 29 of Set 15 | punta cardon
# Processing Record 30 of Set 15 | santa isabel do rio negro
# Processing Record 31 of Set 15 | brnakot
# Processing Record 32 of Set 15 | miri
# Processing Record 33 of Set 15 | pokhara
# Processing Record 34 of Set 15 | port-gentil
# Processing Record 35 of Set 15 | opuwo
# Processing Record 36 of Set 15 | boralday
# Processing Record 37 of Set 15 | les cayes
# Processing Record 38 of Set 15 | buritis
# Processing Record 39 of Set 15 | la cruz
# Processing Record 40 of Set 15 | buala
# Processing Record 41 of Set 15 | caravelas
# Processing Record 42 of Set 15 | matagami
# Processing Record 43 of Set 15 | raahe
# Processing Record 44 of Set 15 | tomatlan
# Processing Record 45 of Set 15 | muisne
# Processing Record 46 of Set 15 | upata
# Processing Record 47 of Set 15 | grand-santi
# Processing Record 48 of Set 15 | sirjan
# Processing Record 49 of Set 15 | hualmay
# Processing Record 50 of Set 15 | fernie
# Processing Record 1 of Set 16 | lazaro cardenas
# Processing Record 2 of Set 16 | oranjemund
# Processing Record 3 of Set 16 | knysna
# Processing Record 4 of Set 16 | lasa
# Processing Record 5 of Set 16 | umm kaddadah
# Processing Record 6 of Set 16 | perevolotskiy
# Processing Record 7 of Set 16 | nadym
# Processing Record 8 of Set 16 | dharampuri
# Processing Record 9 of Set 16 | bermeo
# Processing Record 10 of Set 16 | lakselv
# Processing Record 11 of Set 16 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 16 | antsohihy
# Processing Record 13 of Set 16 | avera
# Processing Record 14 of Set 16 | cabo rojo
# Processing Record 15 of Set 16 | fort saint james
# Processing Record 16 of Set 16 | adra
# Processing Record 17 of Set 16 | korla
# Processing Record 18 of Set 16 | mana
# Processing Record 19 of Set 16 | inhambane
# Processing Record 20 of Set 16 | batagay
# Processing Record 21 of Set 16 | manjakandriana
# Processing Record 22 of Set 16 | hirara
# Processing Record 23 of Set 16 | porto novo
# Processing Record 24 of Set 16 | zhaotong
# Processing Record 25 of Set 16 | rabo de peixe
# Processing Record 26 of Set 16 | dauphin
# Processing Record 27 of Set 16 | ler
# Processing Record 28 of Set 16 | smithers
# Processing Record 29 of Set 16 | gorgan
# Processing Record 30 of Set 16 | hwange
# Processing Record 31 of Set 16 | chingirlau
# Processing Record 32 of Set 16 | taoudenni
# Processing Record 33 of Set 16 | bathsheba
# Processing Record 34 of Set 16 | tekeli
# Processing Record 35 of Set 16 | arman
# Processing Record 36 of Set 16 | coracora
# Processing Record 37 of Set 16 | dzhebariki-khaya
# Processing Record 38 of Set 16 | anloga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 734

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lockport      US  41.59  -88.06     88.00        55           1
# 1         Mataura      NZ -46.19  168.86     45.00        72          71
# 2  Vestmannaeyjar      IS  63.44  -20.27     50.34        78           0
# 3        Yar-Sale      RU  66.83   70.83     52.27        90          27
# 4     Tuktoyaktuk      CA  69.45 -133.04     48.20        76          20
# 5  Candido Mendes      BR  -1.45  -45.72     76.19        88          11
# 6    Porto Walter      BR  -8.27  -72.74     78.06        50          38
# 7        Vallenar      CL -28.57  -70.76     56.28        51           0
# 8        Portland      US  45.52 -122.68     82.99        34           1
# 9          Ixtapa      MX  20.70 -105.20     86.00        74          90
#
#    Wind Speed Current Weather
# 0       16.11           Clear
# 1       11.01            Rain
# 2       13.00           Clear
# 3        5.57          Clouds
# 4       10.29          Clouds
# 5        4.65          Clouds
# 6        2.59          Clouds
# 7        1.61           Clear
# 8        6.93           Clear
# 9        8.05          Clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
